# %%
from func_offshore_figs import *

EP_at_a_gate(region= 'NORTH_ATLANTIC',
             compare = 'AMO', # ENSO  ClimateChange AMO
             gates = [22, 26])
# Out:
# ERA5: total files =  205
# warming level:  3.00
# No of SEASON, ENSEMBLE combo:  100
# region  AT
# CESM: total files =  100
# warming level:  4.00
# No of SEASON, ENSEMBLE combo:  100
# region  AT
# CESM: total files =  100
